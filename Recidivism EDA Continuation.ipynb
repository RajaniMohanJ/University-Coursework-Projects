# %% [markdown]
# Exploratory Data Analysis is continued here, after most of it done in MATLAB.

# %%
# Import useful libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data as a pandas data frame
compas_data = pd.read_csv('compas_for_EDA.csv')

# %%
# Get a glance of data frame
compas_data.head()
# Out:
#    sex  age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0    1   34              0               0                0             0
# 1    1   24              0               0                1             4
# 2    1   41              0               0                0            14
# 3    0   39              0               0                0             0
# 4    1   27              0               0                0             0
#
#    age_cat_25_45  age_cat_Greaterthan45  age_cat_Lessthan25  \
# 0              1                      0                   0
# 1              0                      0                   1
# 2              1                      0                   0
# 3              1                      0                   0
# 4              1                      0                   0
#
#    race_African_American  race_Caucasian  c_charge_degree_F  \
# 0                      1               0                  1
# ...

# %%
# Veiw Descriptive Statistics of the data set
compas_data.describe()
# Out:
#                sex          age  juv_fel_count  juv_misd_count  \
# count  5278.000000  5278.000000    5278.000000     5278.000000
# mean      0.804661    34.449413       0.061387        0.098522
# std       0.396499    11.732619       0.410242        0.517052
# min       0.000000    18.000000       0.000000        0.000000
# 25%       1.000000    25.000000       0.000000        0.000000
# 50%       1.000000    31.000000       0.000000        0.000000
# 75%       1.000000    42.000000       0.000000        0.000000
# max       1.000000    80.000000      10.000000       13.000000
#
#        juv_other_count  priors_count  age_cat_25_45  age_cat_Greaterthan45  \
# count      5278.000000   5278.000000    5278.000000            5278.000000
# mean          0.119174      3.461538       0.573323               0.207654
# std           0.482013      4.875903       0.494641               0.405666
# min           0.000000      0.000000       0.000000               0.000000
# ...

# %%
# Create a Data frame of Descriptive Statistics
Descriptive_Statistics = pd.DataFrame(compas_data.describe())

# %%
# Check the Data frame of Descriptive Statistics
Descriptive_Statistics
# Out:
#                sex          age  juv_fel_count  juv_misd_count  \
# count  5278.000000  5278.000000    5278.000000     5278.000000
# mean      0.804661    34.449413       0.061387        0.098522
# std       0.396499    11.732619       0.410242        0.517052
# min       0.000000    18.000000       0.000000        0.000000
# 25%       1.000000    25.000000       0.000000        0.000000
# 50%       1.000000    31.000000       0.000000        0.000000
# 75%       1.000000    42.000000       0.000000        0.000000
# max       1.000000    80.000000      10.000000       13.000000
#
#        juv_other_count  priors_count  age_cat_25_45  age_cat_Greaterthan45  \
# count      5278.000000   5278.000000    5278.000000            5278.000000
# mean          0.119174      3.461538       0.573323               0.207654
# std           0.482013      4.875903       0.494641               0.405666
# min           0.000000      0.000000       0.000000               0.000000
# ...

# %%
#Descriptive_Statistics.to_csv('compas_Desc_Stats.csv')

# %%
# Assign a variable to Correlation matrix of the data frame
Compas_Correlation = compas_data.corr()

# %%
# Display correlations matrix of the data frame
Compas_Correlation
# Out:
#                             sex       age  juv_fel_count  juv_misd_count  \
# sex                    1.000000 -0.010781       0.059753        0.054145
# age                   -0.010781  1.000000      -0.050695       -0.111448
# juv_fel_count          0.059753 -0.050695       1.000000        0.098343
# juv_misd_count         0.054145 -0.111448       0.098343        1.000000
# juv_other_count        0.066303 -0.177955       0.056913        0.263107
# priors_count           0.127803  0.131840       0.193022        0.272328
# age_cat_25_45         -0.010536 -0.218252       0.034780        0.031766
# age_cat_Greaterthan45  0.003642  0.830881      -0.057253       -0.095749
# age_cat_Lessthan25     0.009027 -0.553896       0.014559        0.055919
# race_African_American  0.069502 -0.210987       0.071792        0.089969
# race_Caucasian        -0.069502  0.210987      -0.071792       -0.089969
# c_charge_degree_F      0.063162 -0.106173       0.045401        0.033141
# ...

# %%
# Plot the correlation matrix as a heatmap
plt.style = sns
plt.figure(figsize=(15,15))
sns.heatmap(Compas_Correlation,annot=True,linewidths=1,)
#plt.savefig("heatmap.png", bbox_inches="tight", pad_inches=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# End of Exploratory Data Analysis.
